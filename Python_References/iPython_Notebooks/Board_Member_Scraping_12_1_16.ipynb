# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

#required encoding for scraping, otherwise defaults to unicode and screws things up
import sys;
reload(sys);
sys.setdefaultencoding("utf8")

# %%
#load URLs of S&P 500 companies
BASE_URL = [
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=MMM',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ABT',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ABBV',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ACN',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ATVI',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=AYI',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ADBE',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=AAP',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=AES',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=AET',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=AFL',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=AMG',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=A',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=APD',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=AKAM',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ALK',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ALB',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=AGN',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=LNT',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ALXN',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ALLE',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ADS',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ALL',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=GOOGL',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=GOOG',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=MO',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=AMZN',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=AEE',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=AAL',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=AEP',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=AXP',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=AIG',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=AMT',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=AWK',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=AMP',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ABC',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=AME',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=AMGN',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=APH',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=APC',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ADI',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ANTM',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=AON',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=APA',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=AIV',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=AAPL',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=AMAT',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ADM',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ARNC',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=AJG',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=AIZ',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=T',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ADSK',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ADP',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=AN',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=AZO',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=AVB',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=AVY',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=BHI',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=BLL',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=BAC',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=BK',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=BCR',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=BAX',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=BBT',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=BDX',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=BBBY',

'http://www.reuters.com/finance/stocks/companyOfficers?symbol=BBY',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=BIIB',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=BLK',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=HRB',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=BA',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=BWA',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=BXP',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=BSX',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=BMY',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=AVGO',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=BFb.N',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CHRW',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CA',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=COG',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CPB',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=COF',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CAH',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=HSIC',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=KMX',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CCL',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CAT',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CBG',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CBS',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CELG',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CNC',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CNP',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CTL',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CERN',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CF',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=SCHW',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CHTR',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CHK',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CVX',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CMG',

'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CHD',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CI',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=XEC',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CINF',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CTAS',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CSCO',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=C',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CFG',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CTXS',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CLX',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CME',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CMS',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=COH',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=KO',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CTSH',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CL',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CMCSA.O',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CMA',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CAG',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CXO',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=COP',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ED',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=STZ',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=GLW',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=COST',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=COTY',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CCI',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CSRA',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CSX',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CMI',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CVS',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=DHI',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=DHR',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=DRI',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=DVA',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=DE',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=DLPH',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=DAL',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=XRAY',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=DVN',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=DLR',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=DFS',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=DISCA',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=DISCK',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=DG',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=DLTR',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=D',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=DOV',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=DOW',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=DPS',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=DTE',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=DD',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=DUK',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=DNB',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ETFC',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=EMN',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ETN',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=EBAY',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ECL',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=EIX',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=EW',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=EA',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=EMR',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ENDP',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ETR',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=EOG',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=EQT',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=EFX',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=EQIX',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=EQR',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ESS',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=EL',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ES',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=EXC',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=EXPE',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=EXPD',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ESRX',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=EXR',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=XOM',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=FFIV',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=FB',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=FAST',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=FRT',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=FDX',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=FIS',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=FITB',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=FSLR',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=FE',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=FISV',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=FLIR',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=FLS',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=FLR',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=FMC',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=FTI',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=FL',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=F',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=FTV',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=FBHS',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=BEN',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=FCX',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=FTR',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=GPS',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=GRMN',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=GD',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=GE',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=GGP',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=GIS',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=GM',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=GPC',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=GILD',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=GPN',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=GS',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=GT',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=GWW',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=HAL',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=HBI',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=HOG',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=HAR',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=HRS',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=HIG',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=HAS',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=HCA',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=HCP',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=HP',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=HES',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=HPE',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=HOLX',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=HD',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=HON',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=HRL',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=HST',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=HPQ',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=HUM',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=HBAN',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ITW',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ILMN',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=IR',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=INTC',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ICE',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=IBM',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=IP',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=IPG',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=IFF',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=INTU',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ISRG',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=IVZ',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=IRM',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=JEC',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=JBHT',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=SJM',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=JNJ',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=JCI',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=JPM',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=JNPR',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=KSU',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=K',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=KEY',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=KMB',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=KIM',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=KMI',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=KLAC',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=KSS',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=KHC',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=KR',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=LB',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=LLL',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=LH',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=LRCX',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=LM',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=LEG',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=LEN',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=LVLT',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=LUK',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=LLY',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=LNC',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=LLTC',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=LKQ',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=LMT',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=L',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=LOW',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=LYB',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=MTB',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=MAC',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=M',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=MNK',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=MRO',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=MPC',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=MAR',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=MMC',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=MLM',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=MAS',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=MA',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=MAT',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=MKC',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=MCD',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=MCK',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=MJN',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=MDT',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=MRK',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=MET',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=MTD',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=KORS',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=MCHP',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=MU',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=MSFT',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=MHK',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=TAP',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=MDLZ',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=MON',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=MNST',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=MCO',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=MS',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=MOS',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=MSI',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=MUR',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=MYL',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=NDAQ',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=NOV',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=NAVI',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=NTAP',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=NFLX',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=NWL',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=NFX',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=NEM',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=NWSA',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=NWS',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=NEE',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=NLSN',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=NKE',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=NI',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=NBL',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=JWN',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=NSC',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=NTRS',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=NOC',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=NRG',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=NUE',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=NVDA',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ORLY',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=OXY',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=OMC',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=OKE',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ORCL',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=OI',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=PCAR',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=PH',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=PDCO',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=PAYX',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=PYPL',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=PNR',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=PBCT',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=PEP',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=PKI',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=PRGO',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=PFE',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=PCG',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=PM',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=PSX',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=PNW',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=PXD',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=PBI',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=PNC',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=RL',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=PPG',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=PPL',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=PX',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=PCLN',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=PFG',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=PG',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=PGR',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=PLD',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=PRU',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=PEG',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=PSA',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=PHM',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=PVH',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=QRVO',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=PWR',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=QCOM',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=DGX',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=RRC',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=RTN',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=O',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=RHT',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=REGN',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=RF',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=RSG',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=RAI',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=RHI',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ROK',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=COL',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ROP',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ROST',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=RCL',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=R',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=CRM',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=SCG',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=SLB',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=SNI',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=STX',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=SEE',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=SRE',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=SHW',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=SIG',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=SPG',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=SWKS',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=SLG',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=SNA',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=SO',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=LUV',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=SWN',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=SE',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=SPGI',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=STJ',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=SWK',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=SPLS',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=SBUX',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=STT',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=SRCL',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=SYK',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=STI',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=SYMC',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=SYF',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=SYY',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=TROW',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=TGT',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=TEL',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=TGNA',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=TDC',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=TSO',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=TXN',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=TXT',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=COO',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=HSY',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=TRV',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=TMO',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=TIF',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=TWX',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=TJX',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=TMK',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=TSS',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=TSCO',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=TDG',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=RIG',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=TRIP',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=FOXA',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=FOX',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=TSN',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=UDR',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ULTA',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=USB',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=UA',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=UA.C',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=UNP',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=UAL',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=UNH',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=UPS',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=URI',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=UTX',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=UHS',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=UNM',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=URBN',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=VFC',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=VLO',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=VAR',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=VTR',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=VRSN',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=VRSK',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=VZ',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=VRTX',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=VIAB',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=V',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=VNO',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=VMC',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=WMT',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=WBA',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=DIS',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=WM',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=WAT',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=WFC',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=HCN',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=WDC',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=WU',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=WRK',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=WY',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=WHR',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=WFM',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=WMB',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=WLTW',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=WEC',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=WYN',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=WYNN',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=XEL',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=XRX',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=XLNX',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=XL',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=XYL',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=YHOO',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=YUM',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ZBH',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ZION',
'http://www.reuters.com/finance/stocks/companyOfficers?symbol=ZTS',
]

# %%
#loading empty array for board members
board_members = []

for b in BASE_URL:
    html = requests.get(b).text
    soup = BeautifulSoup(html, "html.parser")
    officer_table = soup.find('table', {"class" : "dataTable"})
   
    #clause needed to skip any companies without board member tables
    try:
        for row in officer_table.find_all('tr'):
            cols = row.find_all('td')
            if len(cols) == 4:
                board_members.append((b, cols[0].text.strip(), cols[1].text.strip(), cols[2].text.strip(), cols[3].text.strip()))
    except: pass

# %%
#convert output to array, check length
board_array = np.asarray(board_members)
len(board_array)
# Out:
# 9903

# %%
#convert arrary to dataframe
df = pd.DataFrame(board_array)

# %%
#rename columns, check output
df.columns = ['URL', 'Name', 'Age','Year_Joined', 'Title']
df.head(10000)
# Out:
#                                                     URL                 Name  \
# 0     http://www.reuters.com/finance/stocks/companyO...          Inge Thulin
# 1     http://www.reuters.com/finance/stocks/companyO...   Nicholas Gangestad
# 2     http://www.reuters.com/finance/stocks/companyO...         James Bauman
# 3     http://www.reuters.com/finance/stocks/companyO...      Joaquin Delgado
# 4     http://www.reuters.com/finance/stocks/companyO...         Frank Little
# 5     http://www.reuters.com/finance/stocks/companyO...        Michael Roman
# 6     http://www.reuters.com/finance/stocks/companyO...             Hak Shin
# 7     http://www.reuters.com/finance/stocks/companyO...         Michael Vale
# 8     http://www.reuters.com/finance/stocks/companyO...      Ashish Khandpur
# 9     http://www.reuters.com/finance/stocks/companyO...            Ivan Fong
# 10    http://www.reuters.com/finance/stocks/companyO...      Marlene McGrath
# ...

# %%
df.to_csv('/Users/erikrood/desktop/board_members.csv')
