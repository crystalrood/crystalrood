# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np

# %%
traffic_stations = pd.read_csv('/Users/erikrood/desktop/traffic_counting_stations.csv', error_bad_lines=False) 
#traffic_counts = pd.read_csv('/Users/erikrood/desktop/iPython_datasets/hourly_traffic_counts.csv')

# %%
traffic_stations.head()
# Out:
#   Year_Record State_Code Station_Id Travel_Dir Travel_Lane F_System Num_Lanes  \
# 0        2015          2        101          1           1        1         1
# 1        2015          2        101          5           1        1         1
# 2        2015          2        102          1           1        1         2
# 3        2015          2        102          1           2        1         2
# 4        2015          2        102          5           1        1         2
#
#   Sample_Type_Volume Num_Lanes_Volume Method_Volume     ...     NHS  \
# 0                  T                1             3     ...       1
# 1                  T                1             3     ...       1
# 2                  T                2             3     ...       1
# 3                  T                2             3     ...       1
# 4                  T                2             3     ...       1
#
#   Posted_Route_Signing Posted_Signed_Route Con_Route_Signing Con_Signed_Route  \
# ...
